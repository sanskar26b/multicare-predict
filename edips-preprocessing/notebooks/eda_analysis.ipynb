# %% [markdown]
# # EDIPS - EDA Analysis
# This notebook provides a detailed walkthrough of the Exploratory Data Analysis for the infection prediction project.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from preprocessing.config import TRAINING_READY_PATH

df = pd.read_csv(TRAINING_READY_PATH)
df.head()

# %%
df.info()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False)
plt.title('Missing Values Heatmap')
